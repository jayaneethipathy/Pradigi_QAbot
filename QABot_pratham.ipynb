# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import time

# Function to fetch and parse a webpage
def fetch_page(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        return BeautifulSoup(response.text, 'html.parser')
    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

# Function to get all internal links from a webpage (limited to 5)
def get_internal_links(base_url, soup, limit=5):
    internal_links = set()
    count = 0
    for link in soup.find_all('a', href=True):
        if count >= limit:
            break
        href = link['href']
        full_url = urljoin(base_url, href)
        if urlparse(full_url).netloc == urlparse(base_url).netloc:
            internal_links.add(full_url)
            count += 1
    return internal_links

# Function to crawl the website
def crawl_website(base_url, link_limit=5):
    to_visit = {base_url}
    visited = set()
    while to_visit:
        current_url = to_visit.pop()
        if current_url not in visited:
            print(f"Crawling: {current_url}")
            visited.add(current_url)
            soup = fetch_page(current_url)
            if soup:
                internal_links = get_internal_links(base_url, soup, link_limit)
                to_visit.update(internal_links - visited)
            time.sleep(1)  # Respectful crawling by adding delay
    return visited

# Base URL of the website to crawl
base_url = 'https://www.pratham.org'

# Start crawling
urls = crawl_website(base_url,100)

# Output the results
print(f"Total pages found: {len(urls)}")
for page in urls:
    print(page)

import requests
from bs4 import BeautifulSoup
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
import string
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# Ensure you have the necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Function to scrape a webpage
def scrape_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup

# Function to extract relevant data
def extract_data(soup):
    data = []
    for p in soup.find_all('p'):
        data.append(p.get_text())
    return data


# Collect data
all_data = []
for url in urls:
    soup = scrape_page(url)
    data = extract_data(soup)
    all_data.extend(data)

# Convert to DataFrame for further processing
df = pd.DataFrame(all_data, columns=['text'])

# Clean text data
def clean_text(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    return ' '.join(tokens)

df['cleaned_text'] = df['text'].apply(clean_text)

# Create TF-IDF matrix
vectorizer = TfidfVectorizer(max_features=50)
X = vectorizer.fit_transform(df['cleaned_text'])
feature_names = vectorizer.get_feature_names_out()

# Extract top 50 features for each document
def extract_summary(row):
    indices = X[row.name].nonzero()[1]
    top_features = [feature_names[i] for i in indices]
    return ' '.join(top_features)

df['summary'] = df.apply(extract_summary, axis=1)

# Load model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Function to generate a response
def generate_response(question, knowledge_base):
    context = ' '.join(knowledge_base[:5])  # Using a subset of the knowledge base for clarity
    input_text = f"Context: {context}\nQ: {question}\nA:"
    inputs = tokenizer.encode(input_text, return_tensors='pt')
    max_input_length = inputs.shape[1]
    # Adjust max_length to accommodate both input length and generated tokens
    outputs = model.generate(
        inputs, 
        max_length=max_input_length + 50,  # Ensure space for generating new tokens
        num_return_sequences=1, 
        pad_token_id=tokenizer.eos_token_id
    )
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response

# Combine summaries for the knowledge base
knowledge_base = df['summary'].tolist()

# Example queries
questions = [
    "What is Pratham's mission?",
    "How does Pratham help in education?",
    "Where is Pratham located?",
    "What are the latest updates from Pratham?",
    "How can I contact Pratham?"
]

# Generate responses for each question
for question in questions:
    response = generate_response(question, knowledge_base)
    print(f"Q: {question}\nA: {response}\n")

df['summary']
# Out:
# Crawling: https://www.pratham.org
# Crawling: https://www.pratham.org/about/board/
# Crawling: https://www.pratham.org/2019/05/21/vibha-paul/
# Crawling: https://www.pratham.org/about/leadership/
# Crawling: https://www.pratham.org/about/recognition/
# Crawling: https://www.pratham.org/get-involved/donate
# Error fetching https://www.pratham.org/get-involved/donate: Exceeded 30 redirects.
# Crawling: https://www.pratham.org/2019/06/03/csr-leader-award-by-ceo-india-to-co-founders-madhav-chavan-farida-lambay/
# Crawling: https://www.pratham.org/slider/second-chance-slider/
# Crawling: https://www.pratham.org/programs/education/
# Crawling: https://www.pratham.org/contact/
# Crawling: https://www.pratham.org/2019/05/04/arvind-sanger/
# Crawling: https://www.pratham.org/2019/06/03/agent-of-social-change-as-part-of-gq-men-of-the-year-awards-to-madhav-chavan-2015/
# Crawling: https://www.pratham.org/2019/05/21/bbva-foundation-frontiers-of-knowledge-award-2014/
# Crawling: https://www.pratham.org/2019/12/25/vilas-gadkari-2/
# Crawling: https://www.pratham.org/2019/06/03/business-today-award-for-one-of-the-most-powerful-women-in-impact-to-rukmini-banerji-2018-2/
# Crawling: https://www.pratham.org/2019/02/10/the-kravis-prize-in-leadership-2010/
# Crawling: https://www.pratham.org/resources/publications/
# Crawling: https://www.pratham.org/2019/05/04/vijay-goradia/
# Crawling: https://www.pratham.org/about/hamara-gaon/
# Crawling: https://www.pratham.org/impact/
# Crawling: https://www.pratham.org/2019/05/04/nirmal-jain/
# Crawling: https://www.pratham.org/covid-19-response/prathams-community-based-campaign-for-learning-readiness-catch-up/
# Crawling: https://www.pratham.org/programs/education/vocational-training/
# Crawling: https://www.pratham.org/2019/05/07/ms-farida-lambay/
# Crawling: https://www.pratham.org/impact/?dps_paged=2
# Crawling: https://www.pratham.org/slider/ece-slider/
# Crawling: https://www.pratham.org/2019/05/04/dinyar-s-devitre/
# Crawling: https://www.pratham.org/2023/09/12/ragini/
# Crawling: https://www.pratham.org/about/legal-financial-information/
# Crawling: https://www.pratham.org/impact/?dps_paged=1
# Crawling: https://www.pratham.org/wp-content/uploads/2021/01/PEF-Q4-FY-2019-20-ACK.pdf
# Crawling: https://www.pratham.org/2019/05/21/the-global-journal-named-pratham-as-one-of-the-top-100-ngos-in-the-world-2012-2013/
# Crawling: https://www.pratham.org/2023/12/05/rukmini-banerji-co-authors-blog-on-fighting-learning-crisis-with-world-banks-mamta-murthi/
# Crawling: https://www.pratham.org/2019/06/03/ht-for-mumbai-changemaker-title-under-the-education-category-to-farida-lambay-2016/
# Crawling: https://www.pratham.org/get-involved/internships/
# Crawling: https://www.pratham.org/about/teaching-at-the-right-level/
# Crawling: https://www.pratham.org/2023/12/07/jilanba/
# Crawling: https://www.pratham.org/2019/06/03/qimpro-award-for-excellence-2012/
# Crawling: https://www.pratham.org/mmlc-package/
# Crawling: https://www.pratham.org/wp-content/uploads/2020/11/aserreport2019earlyyearsfinal.pdf
# Crawling: https://www.pratham.org/2023/11/28/childrens-rights-in-the-asia-pacific-region-critical-reflections-on-participation-education-girls-rights-and-child-marriage/
# Crawling: https://www.pratham.org/?page_id=4511
# Error fetching https://www.pratham.org/?page_id=4511: 404 Client Error: Not Found for url: https://www.pratham.org/?page_id=4511
# Crawling: https://www.pratham.org/2019/06/03/times-of-india-social-impact-award-for-pratham-usa-2013/
# Crawling: https://www.pratham.org/2019/05/04/jalaj-dani/
# Crawling: https://www.pratham.org/wp-content/uploads/2022/01/FCRA-DECLARATION-July-2021-to-September-2021.pdf
# Crawling: https://www.pratham.org/about/news/
# Crawling: https://www.pratham.org/2023/09/12/bulti-hembrom/
# Crawling: https://www.pratham.org/slider/aser-2023-beyond-basics/
# Crawling: https://www.pratham.org/programs/
# Crawling: https://www.pratham.org/author/vikram/
# Crawling: https://www.pratham.org/blogs/
# Crawling: https://www.pratham.org/about/partners/
# Crawling: https://www.pratham.org/2019/03/19/priyankas-story-catching-up-at-camp/
# Crawling: https://www.pratham.org/2021/12/04/sulzer/
# Crawling: https://www.pratham.org/2024/02/20/in-chhattisgarh-school-for-dropouts-learning-camps-help-dreams-take-shape/
# Crawling: https://www.pratham.org/2020/10/20/banmali-agrawala/
# Crawling: https://www.pratham.org/programs/education/early-childhood-education-new/
# Crawling: https://www.pratham.org/2019/05/04/dr-rukmini-banerji/
# Crawling: https://www.pratham.org/2021/12/04/google-org/
# Crawling: https://www.pratham.org/2019/06/03/aima-public-service-excellence-award-2013/
# Crawling: https://www.pratham.org/2021/12/04/smft/
# Crawling: https://www.pratham.org/2023/12/14/saraswati/
# Crawling: https://www.pratham.org/2023/11/06/dadi-rajpati/
# Crawling: https://www.pratham.org/programs/education/elementary/
# Crawling: https://www.pratham.org/2020/03/05/sdmc/
# Crawling: https://www.pratham.org#content
# Crawling: https://www.pratham.org/
# Crawling: https://www.pratham.org/publications/policy-briefs
# Error fetching https://www.pratham.org/publications/policy-briefs: 404 Client Error: Not Found for url: https://www.pratham.org/publications/policy-briefs
# Crawling: https://www.pratham.org/2023/10/26/chirag/
# Crawling: https://www.pratham.org/2019/05/04/sanjay-nayar/
# Crawling: https://www.pratham.org/wp-content/uploads/2021/01/PEF-Q2-FY-2019-20-ACK.pdf
# Crawling: https://www.pratham.org/2023/07/20/the-school-of-my-dreams/
# Crawling: https://www.pratham.org/programs/education/digital-initiatives/
# Crawling: https://www.pratham.org/2019/12/25/sanjiv-malhotra/
# Crawling: https://www.pratham.org/2019/03/19/dattatrays-story-shifting-gears/
# Crawling: https://www.pratham.org/2023/10/12/bisro/
# Crawling: https://www.pratham.org/2024/06/21/saraswati-2/
# Crawling: https://www.pratham.org/2024/03/06/jaipur-woman-breaks-barriers-restarts-school-through-second-chance/
# Crawling: https://www.pratham.org/2024/07/01/aarti/
# Crawling: https://www.pratham.org/slider/skilling-slider/
# Crawling: https://www.pratham.org/about/annual-reports/
# Crawling: https://www.pratham.org/2021/12/04/adobe/
# Crawling: https://www.pratham.org/2023/09/12/jaga-and-balia/
# Crawling: https://www.pratham.org/about/
# Crawling: https://www.pratham.org/book-chapters
# Error fetching https://www.pratham.org/book-chapters: 404 Client Error: Not Found for url: https://www.pratham.org/book-chapters
# Crawling: https://www.pratham.org/2019/05/21/wise-prize-for-education-to-madhav-chavan-2012/
# Crawling: https://www.pratham.org/wp-content/uploads/2021

# Crawling: https://www.pratham.org/wp-content/uploads/2021/01/PEF-Q3-FY-2017-18-ACK.pdf
# Crawling: https://www.pratham.org/journal-articles
# Error fetching https://www.pratham.org/journal-articles: 404 Client Error: Not Found for url: https://www.pratham.org/journal-articles
# Crawling: https://www.pratham.org/2023/09/23/jyoti/
# Crawling: https://www.pratham.org/programs/education/early-childhood-education/
# Crawling: https://www.pratham.org/2019/07/11/pg/
# Crawling: https://www.pratham.org/programs/pratham-council-for-vulnerablechildren/
# Crawling: https://www.pratham.org/2019/05/21/recognition-by-the-asia-society-as-asia-game-changer-2014-2/
# Crawling: https://www.pratham.org/2023/11/15/dr-madhav-chavan-and-dr-rukmini-banerji-in-a-podcast-series-with-rohini-nilekani-philanthropies/
# Crawling: https://www.pratham.org/2024/02/21/courage-beneath-a-chaarpai-gujarat-mother-breaks-barriers-shows-potential-for-change/
# Crawling: https://www.pratham.org/2024/07/22/manager-organizational-effectiveness/
# Crawling: https://www.pratham.org/2019/05/21/lui-che-woo-2018-prize-in-the-positive-energy-category-for-eliminating-illiteracy-hong-kong-2018/
# Crawling: https://www.pratham.org/2024/05/28/pawan/
# Crawling: https://www.pratham.org/?page_id=4716
# Error fetching https://www.pratham.org/?page_id=4716: 404 Client Error: Not Found for url: https://www.pratham.org/?page_id=4716
# Crawling: https://www.pratham.org/2023/09/12/chintamoni/
# Crawling: https://www.pratham.org/2023/11/18/pravesh/
# Crawling: https://www.pratham.org/2024/05/28/pawan/
# Crawling: https://www.pratham.org/2023/09/11/tameshwari/
# Crawling: https://www.pratham.org/2023/06/15/content-developer-code-club-pratham-digital/
# Crawling: https://www.pratham.org/2024/05/31/program-coordinator-gujarat/
# Crawling: https://www.pratham.org/wp-content/uploads/2020/11/AssessmentData-in-TaRL-19_9_2017.pdf
# Crawling: https://www.pratham.org/2024/06/18/learning-designer-fitness-program-learning-for-life-domain/
# Crawling: https://www.pratham.org/category/early-year/
# Crawling: https://www.pratham.org/2019/07/09/indostar/
# Crawling: https://www.pratham.org/about/annual-reports/2020-21/
# Crawling: https://www.pratham.org/wp-content/uploads/2023/08/annual_report_2021-2022.pdf
# Crawling: https://www.pratham.org/2023/05/02/mh-state-partnership/
# Crawling: https://www.pratham.org/category/board/
# Crawling: https://www.pratham.org/2023/11/06/dadi-rajpati/
# Crawling: https://www.pratham.org/2019/05/21/dr-rukmini-banerji-3/
# Crawling: https://www.pratham.org/2023/12/14/saraswati/
# Crawling: https://www.pratham.org/2024/07/25/project-coordinator-gurugram-2/
# Crawling: https://www.pratham.org/others
# Error fetching https://www.pratham.org/others: 404 Client Error: Not Found for url: https://www.pratham.org/others
# Crawling: https://www.pratham.org/2023/03/06/mathematics-curriculum/
# Crawling: https://www.pratham.org/get-involved/job-opportunities/
# Crawling: https://www.pratham.org/2019/05/04/pramit-jhaveri/
# Crawling: https://www.pratham.org#page
# Crawling: https://www.pratham.org/2019/07/11/usha-rane/
# Crawling: https://www.pratham.org/2024/07/04/associate-english-program-2/
# Crawling: https://www.pratham.org/2023/09/11/summaia/
# Crawling: https://www.pratham.org/2024/06/18/remote-coordinator/
# Crawling: https://www.pratham.org/programs/education/international-collaborations/
# Error fetching https://www.pratham.org/ar/ar1718.pdf: 404 Client Error: Not Found for url: https://www.pratham.org/ar/ar1718.pdf
# Crawling: https://www.pratham.org/2019/05/21/dr-wilima-wadhwa/
# Crawling: https://www.pratham.org/2019/05/04/deepak-raj/
# Crawling: https://www.pratham.org/2020/01/30/npci/
# Crawling: https://www.pratham.org/2023/12/26/centre-support-associate/
# Crawling: https://www.pratham.org/2024/05/27/senior-media-producer/
# Crawling: https://www.pratham.org/2024/03/27/sanvi/
# Crawling: https://www.pratham.org/2024/03/06/junior-angular-developer/
# Crawling: https://www.pratham.org/category/impact/
# Crawling: https://www.pratham.org/2024/02/19/camal-ka-camp-how-community-mobilisers-volunteers-boost-learning-levels-in-children/
# Crawling: https://www.pratham.org/2024/07/25/manager-program-management-group/
# Crawling: https://www.pratham.org/2024/07/04/junior-associate-human-resource/
# Crawling: https://www.pratham.org/iampratham/
# Crawling: https://www.pratham.org/2019/05/04/ramesh-mangaleswaran/
# Crawling: https://www.pratham.org/wp-content/uploads/2020/10/From-Schooling-to-Learning-for-All-Reorienting-Curriculum-and-Targeting-Instruction_SOF_BP2.pdf
# Crawling: https://www.pratham.org/mmlc-faq/
# Crawling: https://www.pratham.org/2024/06/03/senior-graphic-designer-production/
# Crawling: https://www.pratham.org/2020/08/05/kotak-karma/
# Crawling: https://www.pratham.org/2023/09/23/sarojani/
# Crawling: https://www.pratham.org/wp-content/uploads/2021/08/Pratham-Education-Foundation-FCRA-Declaration-Q4.pdf
# Crawling: https://www.pratham.org/category/news/
# Crawling: https://www.pratham.org/2020/03/05/greenlam/
# Crawling: https://www.pratham.org/category/indian-awards/
# Crawling: https://www.pratham.org/2024/07/25/senior-mel-associate-enable-program/
# Crawling: https://www.pratham.org/covid-19-response/connecting-with-children-learn-and-fun/
# Crawling: https://www.pratham.org/wp-content/uploads/2022/01/FCRA-DECLARATION-October-2021-to-December-2021.pdf
# Crawling: https://www.pratham.org/2023/08/29/madhav-chavan-rukmini-banerji/
# Crawling: https://www.pratham.org/2024/07/04/intern-content-development-and-design-english-program/
# Crawling: https://www.pratham.org/2024/07/16/research-content-associate-for-maths-early-years-content/
# Crawling: https://www.pratham.org/category/girls-women/
# Crawling: https://www.pratham.org/2019/02/10/recognition-by-the-asia-society-as-asia-game-changer-2014/
# Crawling: https://www.pratham.org/wp-content/uploads/2021/01/PEF-Q1-FY-2020-21-ACK.pdf
# Crawling: https://www.pratham.org/2022/07/28/associate-production-digital-content/
# Crawling: https://www.pratham.org/get-involved
# Crawling: https://www.pratham.org/2024/02/13/project-coordinator-gurugram/
# Crawling: https://www.pratham.org/2023/05/26/livelihood-coordinator-efe-pratham/
# Crawling: https://www.pratham.org/category/international-awards/
# Crawling: https://www.pratham.org/2024/05/01/program-coordinator/
# Crawling: https://www.pratham.org/2024/06/03/cinematographer-production-media/
# Crawling: https://www.pratham.org/?p=1797
# Error fetching https://www.pratham.org/?p=1797: 404 Client Error: Not Found for url: https://www.pratham.org/?p=1797
# Crawling: https://www.pratham.org/2019/06/03/ht-for-mumbai-changemaker-title-under-the-education-category-to-farida-lambay-2016/
# Crawling: https://www.pratham.org/2023/09/11/summaia/
# Crawling: https://www.pratham.org/2024/04/22/embracing-second-chances/
# Crawling: https://www.pratham.org/2023/10/06/data-documents-and-consent-manager/
# Crawling: https://www.pratham.org/wp-content/uploads/2021
# Crawling: https://www.pratham.org/2019/03/19/priyankas-story-catching-up-at-camp/
# Crawling: https://www.pratham.org/2023/12/07/jilanba/
# Crawling: https://www.pratham.org/author/vasudha/page/2/
# Crawling: https://www.pratham.org/2024/07/04/intern-girls-and-women-program/
# Crawling: https://www.pratham.org/about
# Crawling: https://www.pratham.org/2023/07/14/dr-rukmini-banerji-ceo-of-pratham-education-foundation-about-the-success-of-aser-and-more/
# Crawling: https://www.pratham.org/2023/03/06/pandemic-and-after/
# Crawling: https://www.pratham.org/2024/02/22/%e0%a4%8f%e0%a4%95-%e0%a4%a6%e0%a4%bf%e0%a4%a8-%e0%a4%ad%e0%a4%be%e0%a4%b0%e0%a4%a4%e0%a5%80-%e0%a4%95%e0%a5%87-%e0%a4%b8%e0%a4%be%e0%a4%a5-%e0%a4%8f%e0%a4%95-%e0%a4%b8%e0%a5%87%e0%a4%95%e0%a4%82/
# Crawling: https://www.pratham.org/2024/02/09/kaleena/
# Crawling: https://www.pratham.org/2024/02/17/animator-pratham-shah-pradigi-innovation-center/
# Crawling: https://www.pratham.org/2019/06/03/csr-leader-award-by-ceo-india-to-co-founders-madhav-chavan-farida-lambay/
# Crawling: https://www.pratham.org/2019/06/03/aima-public-service-excellence-award-2013/
# Crawling: https://www.pratham.org/2024/07/04/intern-content-development-and-design-english-program/
# Crawling: https://www.pratham.org/2023/03/06/india-youth-future/
# Crawling: https://www.pratham.org/2024/06/18/manager-internal-donor-audit/
# Crawling: https://www.pratham.org/2024/02/23/playing-with-barahkhadi-how-children-spread-warmth-in-a-delhi-classroom-one-december-afternoon/
# Crawling: https://www.pratham.org/2023/10/31/rukmini-banerji-co-authors-a-chapter-in-the-oxford-handbook-of-program-design-and-implementation-evaluation/
# Crawling: https://www.pratham.org/2019/03/19/samitas-story-finding-her-technical-direction/
# Crawling: https://www.pratham.org/covid-19-response/crisis-management-initiatives-resources/
# Crawling: https://www.pratham.org/2022/11/21/itc/
# Crawling: https://www.pratham.org/2023/11/15/illustrator/
# Crawling: https://www.pratham.org/2024/07/23/action-researcher-birth-3-years/
# Crawling: https://www.pratham.org/2023/06/07/associate-partnership-and-collaboration-pratham-learning-with-vodafone/
# Crawling: https://www.pratham.org/2023/11/17/dr-rukmini-banerji-on-learning-outcomes-and-implementation-of-nep-2020-at-tedx-iim-ahmedabad/
# Crawling: https://www.pratham.org/2024/05/15/us-aid/
# Crawling: https://www.pratham.org/2024/04/10/program-associate-plumbing/
# Crawling: https://www.pratham.org/category/vocational/
# Crawling: https://www.pratham.org/2024/01/23/program-management-and-communications-associate-early-childhood-education/
# Crawling: https://www.pratham.org/2023/03/06/impact-of-connectivity/
# Crawling: https://www.pratham.org/2021/12/04/ubs/
# Crawling: https://www.pratham.org/2023/06/07/associate-teacher-capacity-development-pratham-learning-with-vodafone/
# Crawling: https://www.pratham.org/author/vasudha/page/3/
# Crawling: https://www.pratham.org/2019/03/19/shivams-story-the-first-priority/
# Crawling: https://www.pratham.org/programs/education/
# Crawling: https://www.pratham.org/2023/03/06/volunteer-engagement/
# Crawling: https://www.pratham.org/2021/12/04/hemant-goradia/
# Crawling: https://www.pratham.org/2023/06/15/content-developer-code-club-pratham-digital/
# Crawling: https://www.pratham.org/2024/05/31/sector-specific-trainer-automotive-4-wheeler-program/
# Crawling: https://www.pratham.org/2023/11/06/state-mel-associate-mh/
# Crawling: https://www.pratham.org/2019/07/09/indostar/
# Crawling: https://www.pratham.org/2019/06/03/qimpro-award-for-excellence-2012/
# Crawling: https://www.pratham.org/2019/03/19/samitas-story-finding-her-technical-direction/
# Crawling: https://www.pratham.org/2023/09/23/jyoti/
# Crawling: https://www.pratham.org/2022/11/21/itc/
# Crawling: https://www.pratham.org/2019/05/21/vibha-paul/
# Crawling: https://www.pratham.org/2019/06/03/empi-indian-express-indian-innovation-award-for-read-india-2009/
# Crawling: https://www.pratham.org/2019/05/21/wise-prize-for-education-to-madhav-chavan-2012/
# Crawling: https://www.pratham.org/2019/07/09/godrej-salon/
# Crawling: https://www.pratham.org/2019/02/10/recognition-by-the-asia-society-as-asia-game-changer-2014/
# Crawling: https://www.pratham.org/2024/06/18/manager-internal-donor-audit/
# Crawling: https://www.pratham.org/2021/12/04/western-digital/
# Crawling: https://www.pratham.org/2024/03/06/associate-remote-second-chance-program/
# Crawling: https://www.pratham.org/category/job-opportunities/communications/
# Crawling: https://www.pratham.org/2023/09/22/renu/
# Crawling: https://www.pratham.org/category/donors/page/2/
# Crawling: https://www.pratham.org/2023/07/20/the-school-of-my-dreams/
# Crawling: https://www.pratham.org/2021/12/04/smft/
# Crawling: https://www.pratham.org/author/pratham/page/3/
# Crawling: https://www.pratham.org/category/news/page/2/
# Crawling: https://www.pratham.org/2019/05/21/bbva-foundation-frontiers-of-knowledge-award-2014/
# Crawling: https://www.pratham.org/covid-19-response/government-partnerships-together-we-are-stronger/
# Crawling: https://www.pratham.org/2019/05/21/recognition-by-the-asia-society-as-asia-game-changer-2014-2/
# Crawling: https://www.pratham.org/2019/05/21/lui-che-woo-2018-prize-in-the-positive-energy-category-for-eliminating-illiteracy-hong-kong-2018/
# Crawling: https://www.pratham.org/2020/03/05/greenlam/
# Crawling: https://www.pratham.org/2024/05/03/associate-partnerships-and-training-creativity-clubs/
# Crawling: https://www.pratham.org/www.ketto.org/mumbaifoodproject
# Error fetching https://www.pratham.org/www.ketto.org/mumbaifoodproject: 404 Client Error: Not Found for url: https://www.pratham.org/www.ketto.org/mumbaifoodproject
# Crawling: https://www.pratham.org/2019/03/19/sunils-story-from-child-laborer-to-champion/
# Crawling: https://www.pratham.org/category/job-opportunities/content-development/
# Crawling: https://www.pratham.org/2024/05/28/content-manager-communications/
# Crawling: https://www.pratham.org/2023/11/01/content-training-associate-maths-grade-1-5/
# Crawling: https://www.pratham.org/2023/10/31/rukmini-banerji-co-authors-a-chapter-in-the-oxford-handbook-of-program-design-and-implementation-evaluation/
# Crawling: https://www.pratham.org/2023/09/23/siddhi/
# Crawling: https://www.pratham.org/2023/09/10/communications-advocacy-state-associate/
# Crawling: https://www.pratham.org/2019/03/19/sumits-story-a-different-track/
# Crawling: https://www.pratham.org/2021/12/04/adobe/
# Crawling: https://www.pratham.org/2020/10/20/banmali-agrawala/
# Crawling: https://www.pratham.org/category/internship-opportunities/
# Crawling: https://www.pratham.org/2021/12/04/education-above-all/
# Crawling: https://www.pratham.org/2021/12/04/ubs/
# Crawling: https://www.pratham.org/2023/03/14/2022-indira-gandhi-award/
# Crawling: https://www.pratham.org/covid-19-response/connecting-with-children-learn-and-fun/
# Crawling: https://www.pratham.org/2023/06/27/nationwide-summer-campaigns-can-plug-school-education-gaps/
# Crawling: https://www.pratham.org/2024/04/24/content-developer-environment-learning-for-life-domain-pratham-digital/
# Crawling: https://www.pratham.org/2019/03/19/dattatrays-story-shifting-gears/
# Crawling: https://www.pratham.org/2023/12/05/rukmini-banerji-co-authors-blog-on-fighting-learning-crisis-with-world-banks-mamta-murthi/
# Crawling: https://www.pratham.org/2023/07/12/content-training-associate-state-english/
# Crawling: https://www.pratham.org/category/job-opportunities/page/2/
# Crawling: https://www.pratham.org/2023/11/01/content-training-associate-maths-grade-10th/
# Crawling: https://www.pratham.org/2024/07/16/research-content-associate-for-maths-early-years-content/
# Crawling: https://www.pratham.org/2023/05/17/%e0%a4%b8%e0%a4%b9%e0%a5%80-%e0%a4%b8%e0%a4%ae%e0%a4%af-%e0%a4%aa%e0%a4%b0-%e0%a4%89%e0%a4%aa%e0%a4%af%e0%a5%8b%e0%a4%97%e0%a5%80-%e0%a4%86%e0%a4%82%e0%a4%95%e0%a5%9c%e0%a5%87-%e0%a4%ae%e0%a4%bf/
# Crawling: https://www.pratham.org/2023/01/03/indias-early-years-mathematics-curriculum-continuity-discontinuity-and-progression/
# Crawling: https://www.pratham.org/2023/06/07/master-trainer-teacher-development-science-program-pratham-learning-with-vodafone/
# Crawling: https://www.pratham.org/2023/09/23/siddhi/
# Crawling: https://www.pratham.org/2024/05/31/program-coordinator-gujarat/
# Crawling: https://www.pratham.org/category/job-opportunities/organizational-support/
# Crawling: https://www.pratham.org/2023/09/11/tameshwari/
# Crawling: https://www.pratham.org/2019/02/09/kabita-and-lilis-story-a-special-bond/
# Crawling: https://www.pratham.org/2024/04/24/senior-associate-production-pratham-shah-pradigi-innovation-center/
# Crawling: https://www.pratham.org/category/csr/
# Crawling: https://www.pratham.org/2023/04/05/manager-talent-acquisition-and-onboarding/
# Crawling: https://www.pratham.org/2023/03/14/rukmini-banerji-at-the-gsvemeritus-india-summit/
# Crawling: https://www.pratham.org/2024/06/03/senior-graphic-designer-production/
# Crawling: https://www.pratham.org/2023/01/31/impact-of-connectivity-on-the-future-of-education/
# Crawling: https://www.pratham.org/2023/11/28/childrens-rights-in-the-asia-pacific-region-critical-reflections-on-participation-education-girls-rights-and-child-marriage/
# Crawling: https://www.pratham.org/2021/12/08/a-little-school-by-the-river/
# Crawling: https://www.pratham.org/2024/07/23/action-researcher-birth-3-years/
# Crawling: https://www.pratham.org/2023/09/11/kedarnath/
# Crawling: https://www.pratham.org/2019/07/11/jpal/
# Crawling: https://www.pratham.org/2023/04/04/program-development-associate-pratham-skilling/
# Crawling: https://www.pratham.org/2023/03/06/pandemic-and-after/
# Crawling: https://www.pratham.org/2024/01/23/course-faculty-early-childhood-education/
# Crawling: https://www.pratham.org/2024/02/12/measurement-monitoring-and-evaluation-associate-2/
# Crawling: https://www.pratham.org/2023/03/06/volunteer-engagement/
# Crawling: https://www.pratham.org/2024/01/19/dtp/
# Crawling: https://www.pratham.org/2019/02/10/maulana-abul-kalam-azad-shiksha-puraskar-govt-of-bihar-to-rukmini-banerji-2008/
# Crawling: https://www.pratham.org/2024/04/12/state-content-training-associate/
# Crawling: https://www.pratham.org/get-involved/partner-with-us
# Error fetching https://www.pratham.org/get-involved/partner-with-us: 404 Client Error: Not Found for url: https://www.pratham.org/get-involved/partner-with-us
# Crawling: https://www.pratham.org/2024/05/03/content-training-associate-hindi-language/
# Crawling: https://www.pratham.org/2024/01/19/content-training-associate-maths-grade-1-5-2/
# Crawling: https://www.pratham.org/2019/02/10/maulana-abul-kalam-azad-shiksha-puraskar-govt-of-bihar-to-rukmini-banerji-2008/
# Crawling: https://www.pratham.org/2019/06/03/indian-business-leader-award-by-cnbc-tv-18-to-madhav-chavan-2010/
# Crawling: https://www.pratham.org/category/research-collaborators/
# Crawling: https://www.pratham.org/category/board/page/2/
# Crawling: https://www.pratham.org/2024/07/16/intern-for-maths-early-years-content/
# Crawling: https://www.pratham.org/2019/06/03/times-of-india-social-impact-award-for-pratham-usa-2013/
# Crawling: https://www.pratham.org/2019/06/03/seva-ratna-sahyadri-navratna-award-by-doordarshan-to-farida-lambay-2013/
# Crawling: https://www.pratham.org/2024/06/03/animator-pratham-shah-pradigi-innovation-center-2/
# Crawling: https://www.pratham.org/2019/07/11/ushas-story-mobilizing-action-around-the-world/
# Crawling: https://www.pratham.org/2019/05/04/nirmal-jain/
# Crawling: https://www.pratham.org/covid-19-response/digital-resources-enabling-learning-for-all/
# Crawling: https://www.pratham.org/2023/05/23/associate-teacher-capacity-development-pratham/
# Crawling: https://www.pratham.org/2023/02/10/odisha-winter-camp/
# Crawling: https://www.pratham.org/2024/04/24/content-developer-environment-learning-for-life-domain-pratham-digital/
# Crawling: https://www.pratham.org/2019/05/21/the-global-journal-named-pratham-as-one-of-the-top-100-ngos-in-the-world-2012-2013/
# Crawling: https://www.pratham.org/2023/05/17/%e0%a4%b8%e0%a4%b9%e0%a5%80-%e0%a4%b8%e0%a4%ae%e0%a4%af-%e0%a4%aa%e0%a4%b0-%e0%a4%89%e0%a4%aa%e0%a4%af%e0%a5%8b%e0%a4%97%e0%a5%80-%e0%a4%86%e0%a4%82%e0%a4%95%e0%a5%9c%e0%a5%87-%e0%a4%ae%e0%a4%bf/
# Crawling: https://www.pratham.org/2023/09/23/anju/
# Crawling: https://www.pratham.org/2023/01/13/gautam-kumar-of-bhithiharwa/
# Crawling: https://www.pratham.org/2023/11/15/associate-technology/
# Crawling: https://www.pratham.org/2020/03/05/sdmc/
# Crawling: https://www.pratham.org/2020/03/05/india-foundation/
# Crawling: https://www.pratham.org/2023/11/15/associate-program-manager/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 50
#      47 base_url = 'https://www.pratham.org'
#      49 # Start crawling
# ---> 50 urls = crawl_website(base_url,100)
#      52 # Output the results
#      53 print(f"Total pages found: {len(urls)}")
#
# Cell In[2], line 43, in crawl_website(base_url, link_limit)
#      41             internal_links = get_internal_links(base_url, soup, link_limit)
#      42             to_visit.update(internal_links - visited)
# ---> 43         time.sleep(1)  # Respectful crawling by adding delay
#      44 return visited
#
# KeyboardInterrupt:

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
import string
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# Ensure you have the necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Define important URLs to scrape
important_urls = [
    "https://www.pratham.org/about/",
    "https://www.pratham.org/about/board/",
    "https://www.pratham.org/about/leadership/",
    "https://www.pratham.org/programs/",
    "https://www.pratham.org/programs/learning-with-the-children/",
    "https://www.pratham.org/programs/digital-initiatives/",
    "https://www.pratham.org/programs/vocational-training/",
    "https://www.pratham.org/get-involved/",
    "https://www.pratham.org/get-involved/donate/",
    "https://www.pratham.org/contact/",
    # Add more specific URLs as needed
]

# Function to scrape a webpage
def scrape_page(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        return soup
    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

# Function to extract relevant data
def extract_data(soup):
    data = []
    for p in soup.find_all('p'):
        data.append(p.get_text())
    return data

# Collect data from important URLs
all_data = []
for url in important_urls:
    soup = scrape_page(url)
    if soup:  # Check if the page was successfully fetched
        data = extract_data(soup)
        all_data.extend(data)

# Convert to DataFrame for further processing
df = pd.DataFrame(all_data, columns=['text'])

# Clean text data
def clean_text(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    return ' '.join(tokens)

df['cleaned_text'] = df['text'].apply(clean_text)

# Create TF-IDF matrix
vectorizer = TfidfVectorizer(max_features=50)
X = vectorizer.fit_transform(df['cleaned_text'])
feature_names = vectorizer.get_feature_names_out()

# Extract top 50 features for each document
def extract_summary(row):
    indices = X[row.name].nonzero()[1]
    top_features = [feature_names[i] for i in indices]
    return ' '.join(top_features)

df['summary'] = df.apply(extract_summary, axis=1)

# Load model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

# Function to generate a response
def generate_response(question, knowledge_base):
    context = ' '.join(knowledge_base[:5])  # Using a subset of the knowledge base for clarity
    input_text = f"Context: {context}\nQ: {question}\nA:"
    inputs = tokenizer.encode(input_text, return_tensors='pt')
    max_input_length = inputs.shape[1]
    # Adjust max_length to accommodate both input length and generated tokens
    outputs = model.generate(
        inputs, 
        max_length=max_input_length + 50,  # Ensure space for generating new tokens
        num_return_sequences=1, 
        pad_token_id=tokenizer.eos_token_id
    )
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    # Check if the response is relevant (simple check for now)
    if "contact" in response.lower() or len(response.strip()) < 50:
        return "I'm sorry, I couldn't find the information you're looking for. Please visit Pratham's website or contact them directly for more details."

    return response

# Combine summaries for the knowledge base
knowledge_base = df['summary'].tolist()

# Example queries
questions = [
    "What is Pratham's mission?",
    "How does Pratham help in education?",
    "Where is Pratham located?",
    "What are the latest updates from Pratham?",
    "How can I contact Pratham?",
    "What is Pratham's annual budget?"
]

# Generate responses for each question
for question in questions:
    response = generate_response(question, knowledge_base)
    print(f"Q: {question}\nA: {response}\n")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jayan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jayan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Error fetching https://www.pratham.org/programs/learning-with-the-children/: 404 Client Error: Not Found for url: https://www.pratham.org/programs/learning-with-the-children/
# Error fetching https://www.pratham.org/get-involved/donate/: Exceeded 30 redirects.
# Q: What is Pratham's mission?
# A: Context: pratham learning education india children mumbai pratham education india children also school programs state pratham learning programs years pratham learning education children also programs
# Q: What is Pratham's mission?
# A: Pratham is a non-profit organization that provides educational services to children in the state of India. It is a non-profit organization that provides educational services to children in the state of India. It is a non-profit organization that provides educational services
#
# Q: How does Pratham help in education?
# A: Context: pratham learning education india children mumbai pratham education india children also school programs state pratham learning programs years pratham learning education children also programs
# Q: How does Pratham help in education?
# A: Pratham is a very important part of education. It is a very important part of education. It is a very important part of education. It is a very important part of education. It is a very important part of education. It is a very
#
# Q: Where is Pratham located?
# A: Context: pratham learning education india children mumbai pratham education india children also school programs state pratham learning programs years pratham learning education children also programs
# Q: Where is Pratham located?
# A: Pratham is located in the city of Mumbai.
# Q: What is the age range of the children?
# A: The age range of the children is 18-24 years.
# Q: What is the age range of the children?
#
#
# Q: What are the latest updates from Pratham?
# A: Context: pratham learning education india children mumbai pratham education india children also school programs state pratham learning programs years pratham learning education children also programs
# Q: What are the latest updates from Pratham?
# A: The latest update is from the Pratham Education Programme (PEP) which is a programme of education for children in the state of Maharashtra. The PEP is a programme of education for children in the state of Maharashtra.
# Q: What is the
#
# Q: How can I contact Pratham?
# A: I'm sorry, I couldn't find the information you're looking for. Please visit Pratham's website or contact them directly for more details.
#
# Q: What is Pratham's annual budget?
# A: Context: pratham learning education india children mumbai pratham education india children also school programs state pratham learning programs years pratham learning education children also programs
# Q: What is Pratham's annual budget?
# A: Pratham's annual budget is the amount of money that is spent on education. It is the amount of money that is spent on education that is spent on education.
# Q: What is the average annual budget for Pratham's education?
# A

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
import string
from transformers import pipeline, AutoModelForQuestionAnswering, AutoTokenizer

# Ensure you have the necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')

# Define a hierarchical structure for the URLs
urls_structure = {
    "https://www.pratham.org/about/": [
        "https://www.pratham.org/about/board/",
        "https://www.pratham.org/about/leadership/",
        "https://www.pratham.org/about/partners/",
        "https://www.pratham.org/about/teaching-at-the-right-level/",
        "https://www.pratham.org/about/recognition/",
        "https://www.pratham.org/about/news/",
        "https://www.pratham.org/about/legal-financial-information/"
    ],
    "https://www.pratham.org/programs/": [
        "https://www.pratham.org/programs/education/",
        "https://www.pratham.org/about/hamara-gaon/",
        "https://www.pratham.org/programs/education/early-childhood-education/",
        "https://www.pratham.org/programs/education/elementary/",
        "https://www.pratham.org/programs/education/beyond-elementary/",
        "https://www.pratham.org/programs/education/beyond-elementary/",
        "https://www.pratham.org/programs/education/digital-initiatives/",
        "https://www.pratham.org/programs/digital-initiatives/",
        "https://www.pratham.org/programs/vocational-training/",
        "https://www.pratham.org/programs/pratham-council-for-vulnerablechildren/",
        "https://www.pratham.org/programs/education/aser/"
    ],
    "https://www.pratham.org/get-involved/": [
        "https://www.pratham.org/get-involved/job-opportunities/",
        "https://www.pratham.org/get-involved/internships/"
    ],
    "https://www.pratham.org/contact/": [
        "https://www.pratham.org/contact/"
    ]
}

# Function to scrape a webpage
def scrape_page(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        return soup
    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
        return None

# Function to extract relevant data
def extract_data(soup):
    data = []
    if soup:
        for p in soup.find_all('p'):
            data.append(p.get_text())
    return data

# Collect data from all URLs in the structure
all_data = []
for main_url, sub_urls in urls_structure.items():
    soup = scrape_page(main_url)
    if soup:  # Check if the main page was successfully fetched
        data = extract_data(soup)
        all_data.extend(data)
    for sub_url in sub_urls:
        soup = scrape_page(sub_url)
        if soup:  # Check if the sub-page was successfully fetched
            data = extract_data(soup)
            all_data.extend(data)

# Convert to DataFrame for further processing
df = pd.DataFrame(all_data, columns=['text'])

# Clean text data
def clean_text(text):
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    return ' '.join(tokens)

df['cleaned_text'] = df['text'].apply(clean_text)

# Create TF-IDF matrix
vectorizer = TfidfVectorizer(max_features=50)
X = vectorizer.fit_transform(df['cleaned_text'])
feature_names = vectorizer.get_feature_names_out()

# Extract top 50 features for each document
def extract_summary(row):
    indices = X[row.name].nonzero()[1]
    top_features = [feature_names[i] for i in indices]
    return ' '.join(top_features)

df['summary'] = df.apply(extract_summary, axis=1)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jayan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jayan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from transformers import pipeline, AutoModelForQuestionAnswering, AutoTokenizer
import pandas as pd

# Load model and tokenizer from Hugging Face
model_name = "deepset/bert-base-cased-squad2"
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Initialize the QA pipeline
qa_pipeline = pipeline("question-answering", model=model, tokenizer=tokenizer)

# Create a combined knowledge base from the summary column
knowledge_base = " ".join(df['summary'].dropna().tolist())

# Function to generate a response
def generate_response(question, knowledge_base):
    if not knowledge_base.strip():
        return "I'm sorry, I couldn't find the information you're looking for. Please visit Pratham's website or contact them directly for more details."

    result = qa_pipeline(question=question, context=knowledge_base)
    answer = result.get('answer', '')

    if not answer:
        return "I'm sorry, I couldn't find the information you're looking for. Please visit Pratham's website or contact them directly for more details."
    return answer

# Example queries
questions = [
    "What is Pratham's mission?",
    "How does Pratham help in education?",
    "Where is Pratham located?",
    "What are the latest updates from Pratham?",
    "How can I contact Pratham?"
]

# Generate responses for each question
for question in questions:
    response = generate_response(question, knowledge_base)
    print(f"Q: {question}\nA: {response}\n")
# Out:
# Some weights of the model checkpoint at deepset/bert-base-cased-squad2 were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Q: What is Pratham's mission?
# A: children  learning   job opportunities
#
# Q: How does Pratham help in education?
# A: pratham vocational training
#
# Q: Where is Pratham located?
# A: india
#
# Q: What are the latest updates from Pratham?
# A: programs education vocational training education annual status report
#
# Q: How can I contact Pratham?
# A: contact number chavan maharashtra 022

# %%
df['summary']
# Out:
# 0       pratham learning education india children mumbai
# 1                                                pratham
# 2      education india children also school programs ...
# 3                        pratham learning programs years
# 4      pratham learning education children also programs
#                              ...
# 349                                         delhi office
# 350    delhi enclave 1st floor new email infoprathamo...
# 351                                        mumbai office
# 352    mumbai floor email infoprathamorg contact numb...
# 353
# Name: summary, Length: 354, dtype: object
